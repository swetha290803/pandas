# %% [markdown]
# useful for data preprocessing and analysis
# pandas has 2 objects: dataframe and series
# PANDAS DATAFRAME : 2D tabular datastructure with labeled rows and columns

# %%
#importing pandas
import pandas as pd
import numpy as np

# %%
#in order to import dataset
from sklearn.datasets import load_boston
# Load the dataset
boston = load_boston()
#currently this dataset in unaavailabele to import direct from online due to ethical issues so i downloaded directly

# %% [markdown]
# here we are creating data frame in order to keep the data in strcutured format

# %%
home_df = pd.read_csv('/content/homeprices.csv')

# %%
print(home_df)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
home_df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
#shape
home_df.shape
# Out:
# (5, 2)

# %%
#checking datatype
type(home_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# importing data from csv file to data frame
# csv file means comma spearted values which cannot be analyse hence we will convert inti data frames

# %%
#here my diabetes dataset is an csv file hence i am converting it to dataframe
diabetes_df = pd.read_csv('/content/diabetes.csv')

# %%
#after converting check its type
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()#print first five rows
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.tail()#print last five rows
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# converting the excel file into dataframe

# %%
#here i am taking example as areas dataset
areas_df = pd.read_excel('/content/areas.csv')

# %% [markdown]
# exporting a dataframe to csv file

# %%
#here i am taking examplle of homeprices df
home_df.to_csv('home_csv')
#here home_csv is the file name we can give any thing we want

# %% [markdown]
# exporting a dataframe to excel file

# %%
#wee can export any df to excel file , here i am taking again home df as an example
home_df.to_excel('home_excel')

# %% [markdown]
# creating a random dataframe

# %%
random_df = pd.DataFrame(np.random.rand(20,10))
random_df.shape
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.197329  0.700020  0.212388  0.423909  0.785615  0.511036  0.232647
# 1  0.709282  0.107537  0.405726  0.523504  0.060300  0.852605  0.206241
# 2  0.952770  0.765303  0.486233  0.041971  0.688474  0.720656  0.901438
# 3  0.466893  0.709944  0.207424  0.818786  0.919774  0.344486  0.736370
# 4  0.245611  0.704226  0.079475  0.551265  0.162070  0.445890  0.066691
#
#           7         8         9
# 0  0.300702  0.446077  0.678534
# 1  0.859357  0.114481  0.331696
# 2  0.768043  0.902768  0.979804
# 3  0.041125  0.909686  0.790236
# 4  0.051923  0.324618  0.645675

# %% [markdown]
# inspecting a dataframe

# %%
#finding no of rows and columns
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# Information about dataframe

# %%
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#finding no of missing values
diabetes_df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#count no of specific values based on idexes
diabetes_df.value_counts('Outcome')
#ouctome means no of ones and zeroes
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
#group values based on mean
diabetes_df.groupby('Outcome').mean()
#here we will get two tables based on zeros and ones by taking the mean means average of each value
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# STATISTICAL MEASURES

# %%
#count no of values
diabetes_df.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
#mean value column wise
diabetes_df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
#standard deviation
diabetes_df.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
#min and max values
diabetes_df.min()
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
#to know all statistcial measures
diabetes_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# MANIPULATING DF

# %%
#adding a column to df
home_df['price']
#here [] adds an column to the dataset
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
#removing a row
home_df.drop(index = 0,axis = 0)
#for row axis = 0 and for column axis = 1
#in order to drop a row permanently we can weite in this way:
#home_df1 = home_df.drop(index = 0,axis = 0)''' #then this will print new dataset by dropping the selected row
# Out:
#    area   price
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
#drop a column
diabetes_df.drop(columns = 'BMI',axis = 1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0              6      148             72             35        0
# 1              1       85             66             29        0
# 2              8      183             64              0        0
# 3              1       89             66             23       94
# 4              0      137             40             35      168
# ..           ...      ...            ...            ...      ...
# 763           10      101             76             48      180
# 764            2      122             70             27        0
# 765            5      121             72             23      112
# 766            1      126             60              0        0
# 767            1       93             70             31        0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# ...

# %%
#printing(locating) partciluar row using index value
diabetes_df.iloc[2]
# Out:
# Pregnancies                   8.000
# Glucose                     183.000
# BloodPressure                64.000
# SkinThickness                 0.000
# Insulin                       0.000
# BMI                          23.300
# DiabetesPedigreeFunction      0.672
# Age                          32.000
# Outcome                       1.000
# Name: 2, dtype: float64

# %%
#printing parrticular column
print(diabetes_df.iloc[:,0])#prints first column
# Out:
# 0       6
# 1       1
# 2       8
# 3       1
# 4       0
#        ..
# 763    10
# 764     2
# 765     5
# 766     1
# 767     1
# Name: Pregnancies, Length: 768, dtype: int64

# %%
print(diabetes_df.iloc[:,1])#prints second column
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64

# %%
print(diabetes_df.iloc[:,-1])#prints all values from lastcolumn
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# CORRELATION: find relationship between various columns(col are also knwon as variables)
# coreelation is of two types:
# 1.positive-- one value increases if other increases
# 2.negative---one value decreases if other decreases

# %%
diabetes_df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...
